test_accu_color_m3_s3 = np.array([0.540625, 0.5395833333333333, 0.5322916666666667, 0.546875, 0.525, 0.5854166666666667, 0.63125, 0.625, 0.6385416666666667, 0.6458333333333334])
train_accu_blur_m3_s3 = np.array([0.5807291666666666, 0.59140625, 0.5994791666666667, 0.6595052083333334, 0.698046875, 0.73828125, 0.7356770833333334, 0.7712239583333333, 0.8171875, 0.8455729166666667])
test_accu_blur_m3_s3 = np.array([0.5354166666666667, 0.5333333333333333, 0.55625, 0.6083333333333333, 0.6291666666666667, 0.65, 0.6322916666666667, 0.659375, 0.6958333333333333, 0.7083333333333334])
train_accu_orignal_m3_s3 = np.array([0.6145833333333334, 0.6145833333333334, 0.6122395833333333, 0.653125, 0.6408854166666667, 0.66953125, 0.69296875, 0.6911458333333333, 0.7005208333333334, 0.6703125])
test_accu_orignal_m3_s3 = np.array([0.5520833333333334, 0.55, 0.5364583333333334, 0.56875, 0.5458333333333333, 0.596875, 0.6291666666666667, 0.6145833333333334, 0.6239583333333333, 0.5958333333333333])

# %% [markdown]
# # Model 1

# %%
data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m1_s1,test_accu_flip_m1_s1),
        'Rotate':np.append(train_accu_rotate_m1_s1,test_accu_rotate_m1_s1),
        'Crop':np.append(train_accu_crop_m1_s1,test_accu_crop_m1_s1),
        'Color':np.append(train_accu_color_m1_s1,test_accu_color_m1_s1),
        'Blur':np.append(train_accu_blur_m1_s1,test_accu_blur_m1_s1),
        'Orignal':np.append(train_accu_orignal_m1_s1,test_accu_orignal_m1_s1),
       }

df1 = pd.DataFrame(data)
df1 = pd.melt(df1, ['Epochs'])
a = np.tile(np.append(np.repeat('Train', 10),np.repeat('Test', 10)),6)
df1['Data'] = a
df1['Seed'] = 1
df1.rename(columns={'variable':'Augmentation'}, inplace = True)

data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m1_s2,test_accu_flip_m1_s2),
        'Rotate':np.append(train_accu_rotate_m1_s2,test_accu_rotate_m1_s2),
        'Crop':np.append(train_accu_crop_m1_s2,test_accu_crop_m1_s2),
        'Color':np.append(train_accu_color_m1_s2,test_accu_color_m1_s2),
        'Blur':np.append(train_accu_blur_m1_s2,test_accu_blur_m1_s2),
        'Orignal':np.append(train_accu_orignal_m1_s2,test_accu_orignal_m1_s2),
       }

df2 = pd.DataFrame(data)
df2 = pd.melt(df2, ['Epochs'])
df2['Data'] = a
df2['Seed'] = 2
df2.rename(columns={'variable':'Augmentation'}, inplace = True)

data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m1_s3,test_accu_flip_m1_s3),
        'Rotate':np.append(train_accu_rotate_m1_s3,test_accu_rotate_m1_s3),
        'Crop':np.append(train_accu_crop_m1_s3,test_accu_crop_m1_s3),
        'Color':np.append(train_accu_color_m1_s3,test_accu_color_m1_s3),
        'Blur':np.append(train_accu_blur_m1_s3,test_accu_blur_m1_s3),
        'Orignal':np.append(train_accu_orignal_m1_s3,test_accu_orignal_m1_s3),
       }

df3 = pd.DataFrame(data)
df3 = pd.melt(df3, ['Epochs'])
df3['Data'] = a
df3['Seed'] = 3
df3.rename(columns={'variable':'Augmentation'}, inplace = True)
m1 = pd.concat([df1,df2,df3])
print(m1)

sns.relplot(
    data=m1, x="Epochs", y="value",
    col="Seed", hue="Augmentation", style="Data",
    kind="line"
)
# Out:
#      Epochs Augmentation     value   Data  Seed
# 0         1         Flip  0.601823  Train     1
# 1         2         Flip  0.559505  Train     1
# 2         3         Flip  0.643750  Train     1
# 3         4         Flip  0.777995  Train     1
# 4         5         Flip  0.770443  Train     1
# ..      ...          ...       ...    ...   ...
# 115       6      Orignal  0.601042   Test     3
# 116       7      Orignal  0.640625   Test     3
# 117       8      Orignal  0.589583   Test     3
# 118       9      Orignal  0.612500   Test     3
# 119      10      Orignal  0.610417   Test     3
#
# [360 rows x 5 columns]

# %% [markdown]
# # Model 2

# %%
data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m2_s1,test_accu_flip_m2_s1),
        'Rotate':np.append(train_accu_rotate_m2_s1,test_accu_rotate_m2_s1),
        'Crop':np.append(train_accu_crop_m2_s1,test_accu_crop_m2_s1),
        'Color':np.append(train_accu_color_m2_s1,test_accu_color_m2_s1),
        'Blur':np.append(train_accu_blur_m2_s1,test_accu_blur_m2_s1),
        'Orignal':np.append(train_accu_orignal_m2_s1,test_accu_orignal_m2_s1),
       }

df1 = pd.DataFrame(data)
df1 = pd.melt(df1, ['Epochs'])
a = np.tile(np.append(np.repeat('Train', 10),np.repeat('Test', 10)),6)
df1['Data'] = a
df1['Seed'] = 1
df1.rename(columns={'variable':'Augmentation'}, inplace = True)

data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m2_s2,test_accu_flip_m2_s2),
        'Rotate':np.append(train_accu_rotate_m2_s2,test_accu_rotate_m2_s2),
        'Crop':np.append(train_accu_crop_m2_s2,test_accu_crop_m2_s2),
        'Color':np.append(train_accu_color_m2_s2,test_accu_color_m2_s2),
        'Blur':np.append(train_accu_blur_m2_s2,test_accu_blur_m2_s2),
        'Orignal':np.append(train_accu_orignal_m2_s2,test_accu_orignal_m2_s2),
       }

df2 = pd.DataFrame(data)
df2 = pd.melt(df2, ['Epochs'])
df2['Data'] = a
df2['Seed'] = 2
df2.rename(columns={'variable':'Augmentation'}, inplace = True)

data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m2_s3,test_accu_flip_m2_s3),
        'Rotate':np.append(train_accu_rotate_m2_s3,test_accu_rotate_m2_s3),
        'Crop':np.append(train_accu_crop_m2_s3,test_accu_crop_m2_s3),
        'Color':np.append(train_accu_color_m2_s3,test_accu_color_m2_s3),
        'Blur':np.append(train_accu_blur_m2_s3,test_accu_blur_m2_s3),
        'Orignal':np.append(train_accu_orignal_m2_s3,test_accu_orignal_m2_s3),
       }

df3 = pd.DataFrame(data)
df3 = pd.melt(df3, ['Epochs'])
df3['Data'] = a
df3['Seed'] = 3
df3.rename(columns={'variable':'Augmentation'}, inplace = True)
m2 = pd.concat([df1,df2,df3])
print(m2)

sns.relplot(
    data=m2, x="Epochs", y="value",
    col="Seed", hue="Augmentation", style="Data",
    kind="line"
)
# Out:
#      Epochs Augmentation     value   Data  Seed
# 0         1         Flip  0.574870  Train     1
# 1         2         Flip  0.586458  Train     1
# 2         3         Flip  0.634896  Train     1
# 3         4         Flip  0.586068  Train     1
# 4         5         Flip  0.523568  Train     1
# ..      ...          ...       ...    ...   ...
# 115       6      Orignal  0.632292   Test     3
# 116       7      Orignal  0.623958   Test     3
# 117       8      Orignal  0.698958   Test     3
# 118       9      Orignal  0.668750   Test     3
# 119      10      Orignal  0.655208   Test     3
#
# [360 rows x 5 columns]

# %% [markdown]
# # Model 3

# %%
data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m3_s1,test_accu_flip_m3_s1),
        'Rotate':np.append(train_accu_rotate_m3_s1,test_accu_rotate_m3_s1),
        'Crop':np.append(train_accu_crop_m3_s1,test_accu_crop_m3_s1),
        'Color':np.append(train_accu_color_m3_s1,test_accu_color_m3_s1),
        'Blur':np.append(train_accu_blur_m3_s1,test_accu_blur_m3_s1),
        'Orignal':np.append(train_accu_orignal_m3_s1,test_accu_orignal_m3_s1),
       }

df1 = pd.DataFrame(data)
df1 = pd.melt(df1, ['Epochs'])
a = np.tile(np.append(np.repeat('Train', 10),np.repeat('Test', 10)),6)
df1['Data'] = a
df1['Seed'] = 1
df1.rename(columns={'variable':'Augmentation'}, inplace = True)

data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m3_s2,test_accu_flip_m3_s2),
        'Rotate':np.append(train_accu_rotate_m3_s2,test_accu_rotate_m3_s2),
        'Crop':np.append(train_accu_crop_m3_s2,test_accu_crop_m3_s2),
        'Color':np.append(train_accu_color_m3_s2,test_accu_color_m3_s2),
        'Blur':np.append(train_accu_blur_m3_s2,test_accu_blur_m3_s2),
        'Orignal':np.append(train_accu_orignal_m3_s2,test_accu_orignal_m3_s2),
       }

df2 = pd.DataFrame(data)
df2 = pd.melt(df2, ['Epochs'])
df2['Data'] = a
df2['Seed'] = 2
df2.rename(columns={'variable':'Augmentation'}, inplace = True)

data = {'Epochs':np.tile(range(1, 11),2), 
        'Flip':np.append(train_accu_flip_m3_s3,test_accu_flip_m3_s3),
        'Rotate':np.append(train_accu_rotate_m3_s3,test_accu_rotate_m3_s3),
        'Crop':np.append(train_accu_crop_m3_s3,test_accu_crop_m3_s3),
        'Color':np.append(train_accu_color_m3_s3,test_accu_color_m3_s3),
        'Blur':np.append(train_accu_blur_m3_s3,test_accu_blur_m3_s3),
        'Orignal':np.append(train_accu_orignal_m3_s3,test_accu_orignal_m3_s3),
       }

df3 = pd.DataFrame(data)
df3 = pd.melt(df3, ['Epochs'])
df3['Data'] = a
df3['Seed'] = 3
df3.rename(columns={'variable':'Augmentation'}, inplace = True)
m3 = pd.concat([df1,df2,df3])
print(m3)

sns.relplot(
    data=m3, x="Epochs", y="value",
    col="Seed", hue="Augmentation", style="Data",
    kind="line"
)
# Out:
#      Epochs Augmentation     value   Data  Seed
# 0         1         Flip  0.611719  Train     1
# 1         2         Flip  0.602474  Train     1
# 2         3         Flip  0.659505  Train     1
# 3         4         Flip  0.580469  Train     1
# 4         5         Flip  0.705078  Train     1
# ..      ...          ...       ...    ...   ...
# 115       6      Orignal  0.596875   Test     3
# 116       7      Orignal  0.629167   Test     3
# 117       8      Orignal  0.614583   Test     3
# 118       9      Orignal  0.623958   Test     3
# 119      10      Orignal  0.595833   Test     3
#
# [360 rows x 5 columns]

# %% [markdown]
# # Plot

# %%
df = pd.concat([m1,m2,m3])
df['Model'] = np.repeat(range(1,4),360)

sns.relplot(
    data=df, x="Epochs", y="value", row = "Model",
    col="Seed", hue="Augmentation", style="Data",
    kind="line"
)
plt.savefig('plot.png')

# %% [markdown]
# # Previous Plots

# %%
epoch = range(1, 11)
# train_accu_flip_m1_s1 = np.array([0.6018229166666667, 0.5595052083333333, 0.64375, 0.7779947916666666, 0.7704427083333333, 0.8515625, 0.895703125, 0.9100260416666667, 0.9143229166666667, 0.855078125])
# test_accu_flip_m1_s1 = np.array([0.590625, 0.5572916666666666, 0.5895833333333333, 0.65, 0.6583333333333333, 0.6802083333333333, 0.6739583333333333, 0.6614583333333334, 0.66875, 0.6197916666666666])
# train_accu_rotate_m1_s1 = np.array([0.5669270833333333, 0.5766927083333333, 0.5947916666666667, 0.6563802083333333, 0.7389322916666666, 0.7408854166666666, 0.78671875, 0.7506510416666666, 0.805859375, 0.8239583333333333])
# test_accu_rotate_m1_s1 = np.array([0.55625, 0.5822916666666667, 0.6166666666666667, 0.6375, 0.70625, 0.6791666666666667, 0.7020833333333333, 0.66875, 0.7104166666666667, 0.671875])
# train_accu_crop_m1_s1 = np.array([0.5506510416666667, 0.5397135416666666, 0.5375, 0.6104166666666667, 0.663671875, 0.6947916666666667, 0.7338541666666667, 0.8231770833333333, 0.8798177083333333, 0.7368489583333333])
# test_accu_crop_m1_s1 = np.array([0.5614583333333333, 0.5479166666666667, 0.5635416666666667, 0.5979166666666667, 0.6145833333333334, 0.6125, 0.5760416666666667, 0.5947916666666667, 0.5791666666666667, 0.6020833333333333])
# train_accu_color_m1_s1 = np.array([0.58984375, 0.6657552083333333, 0.705078125, 0.7736979166666667, 0.8234375, 0.88984375, 0.9126302083333333, 0.49895833333333334, 0.8795572916666666, 0.9209635416666667])
# test_accu_color_m1_s1 = np.array([0.5729166666666666, 0.5583333333333333, 0.590625, 0.596875, 0.59375, 0.6041666666666666, 0.5927083333333333, 0.4635416666666667, 0.58125, 0.5927083333333333])
# train_accu_blur_m1_s1 = np.array([0.63125, 0.6329427083333333, 0.6296875, 0.66171875, 0.7393229166666667, 0.7666666666666667, 0.7971354166666667, 0.8180989583333333, 0.764453125, 0.8845052083333333])
# test_accu_blur_m1_s1 = np.array([0.6083333333333333, 0.6166666666666667, 0.5947916666666667, 0.571875, 0.6427083333333333, 0.6208333333333333, 0.64375, 0.646875, 0.6114583333333333, 0.6052083333333333])
# train_accu_orignal_m1_s1 = np.array([0.5434895833333333, 0.5559895833333334, 0.6177083333333333, 0.6609375, 0.7088541666666667, 0.66171875, 0.8171875, 0.8731770833333333, 0.86171875, 0.925])
# test_accu_orignal_m1_s1 = np.array([0.5041666666666667, 0.5260416666666666, 0.5677083333333334, 0.5833333333333334, 0.60625, 0.546875, 0.596875, 0.6177083333333333, 0.5958333333333333, 0.6010416666666667])

plt.title("Model 1: Train vs Valid Accuracy (Seed 1)")
plt.plot(epoch, train_accu_flip_m1_s1, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m1_s1, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m1_s1, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m1_s1, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m1_s1, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m1_s1, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m1_s1, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m1_s1, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m1_s1, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m1_s1, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m1_s1, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m1_s1, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# epoch = range(1, 11)
# train_accu_flip_m1_s2 = np.array([0.5227864583333334, 0.54609375, 0.5786458333333333, 0.5884114583333333, 0.61015625, 0.574609375, 0.5227864583333334, 0.6067708333333334, 0.6330729166666667, 0.6255208333333333])
# test_accu_flip_m1_s2 = np.array([0.5052083333333334, 0.5333333333333333, 0.5458333333333333, 0.5822916666666667, 0.6020833333333333, 0.565625, 0.5125, 0.5864583333333333, 0.634375, 0.615625])
# train_accu_rotate_m1_s2 = np.array([0.5416666666666666, 0.5897135416666667, 0.635546875, 0.6173177083333333, 0.67890625, 0.6720052083333333, 0.7315104166666667, 0.7484375, 0.7466145833333333, 0.7790364583333333])
# test_accu_rotate_m1_s2 = np.array([0.546875, 0.5625, 0.6114583333333333, 0.615625, 0.6510416666666666, 0.6802083333333333, 0.6854166666666667, 0.6947916666666667, 0.6791666666666667, 0.69375])
# train_accu_crop_m1_s2 = np.array([0.5356770833333333, 0.5549479166666667, 0.5037760416666667, 0.5569010416666667, 0.5625, 0.6118489583333333, 0.610546875, 0.5459635416666667, 0.6053385416666667, 0.5690104166666666])
# test_accu_crop_m1_s2 = np.array([0.5291666666666667, 0.56875, 0.5020833333333333, 0.58125, 0.5864583333333333, 0.6375, 0.6458333333333334, 0.56875, 0.584375, 0.5885416666666666])
# train_accu_color_m1_s2 = np.array([0.5317708333333333, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])
# test_accu_color_m1_s2 = np.array([0.553125, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])
# train_accu_blur_m1_s2 = np.array([0.5822916666666667, 0.6438802083333334, 0.5854166666666667, 0.6266927083333333, 0.677734375, 0.6294270833333333, 0.7138020833333333, 0.7282552083333333, 0.7270833333333333, 0.7579427083333333])
# test_accu_blur_m1_s2 = np.array([0.5697916666666667, 0.5979166666666667, 0.5708333333333333, 0.6, 0.634375, 0.5697916666666667, 0.590625, 0.6270833333333333, 0.646875, 0.6177083333333333])
# train_accu_orignal_m1_s2 = np.array([0.5921875, 0.6809895833333334, 0.7263020833333333, 0.68359375, 0.8015625, 0.8286458333333333, 0.840625, 0.8768229166666667, 0.9072916666666667, 0.91796875])
# test_accu_orignal_m1_s2 = np.array([0.56875, 0.6291666666666667, 0.6260416666666667, 0.6041666666666666, 0.6072916666666667, 0.6041666666666666, 0.5895833333333333, 0.5770833333333333, 0.6052083333333333, 0.590625])

plt.title("Model 1: Train vs Valid Accuracy (Seed 2)")
plt.plot(epoch, train_accu_flip_m1_s2, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m1_s2, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m1_s2, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m1_s2, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m1_s2, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m1_s2, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m1_s2, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m1_s2, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m1_s2, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m1_s2, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m1_s2, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m1_s2, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# epoch = range(1, 11)
# train_accu_flip_m1_s3 = np.array([0.5864583333333333, 0.61484375, 0.53515625, 0.6518229166666667, 0.69140625, 0.7384114583333333, 0.6526041666666667, 0.8493489583333333, 0.9040364583333333, 0.8848958333333333])
# test_accu_flip_m1_s3 = np.array([0.5364583333333334, 0.5604166666666667, 0.553125, 0.5979166666666667, 0.609375, 0.5822916666666667, 0.5364583333333334, 0.6604166666666667, 0.675, 0.6572916666666667])
# train_accu_rotate_m1_s3 = np.array([0.5665364583333333, 0.5850260416666667, 0.6220052083333333, 0.6850260416666667, 0.7130208333333333, 0.7065104166666667, 0.724609375, 0.7772135416666667, 0.8153645833333333, 0.808984375])
# test_accu_rotate_m1_s3 = np.array([0.553125, 0.603125, 0.61875, 0.6375, 0.65625, 0.6583333333333333, 0.671875, 0.7, 0.7, 0.6864583333333333])
# train_accu_crop_m1_s3 = np.array([0.55703125, 0.5592447916666666, 0.54453125, 0.5455729166666666, 0.5578125, 0.553125, 0.569140625, 0.5985677083333333, 0.603515625, 0.5325520833333334])
# test_accu_crop_m1_s3 = np.array([0.55, 0.5572916666666666, 0.5625, 0.5666666666666667, 0.56875, 0.578125, 0.5958333333333333, 0.6125, 0.6229166666666667, 0.5208333333333334])
# train_accu_color_m1_s3 = np.array([0.5872395833333334, 0.6358072916666667, 0.7268229166666667, 0.7852864583333333, 0.7829427083333333, 0.8768229166666667, 0.8477864583333333, 0.9272135416666667, 0.9264322916666666, 0.8356770833333333])
# test_accu_color_m1_s3 = np.array([0.5760416666666667, 0.5322916666666667, 0.5833333333333334, 0.625, 0.5947916666666667, 0.6614583333333334, 0.5947916666666667, 0.6447916666666667, 0.6416666666666667, 0.5916666666666667])
# train_accu_blur_m1_s3 = np.array([0.6096354166666667, 0.5950520833333334, 0.6451822916666666, 0.6682291666666667, 0.642578125, 0.6962239583333333, 0.7276041666666667, 0.7171875, 0.7444010416666667, 0.7205729166666667])
# test_accu_blur_m1_s3 = np.array([0.5625, 0.5677083333333334, 0.61875, 0.63125, 0.5854166666666667, 0.60625, 0.6385416666666667, 0.6208333333333333, 0.5979166666666667, 0.59375])
# train_accu_orignal_m1_s3 = np.array([0.55078125, 0.57109375, 0.69140625, 0.5619791666666667, 0.5822916666666667, 0.6260416666666667, 0.6458333333333334, 0.6278645833333333, 0.659375, 0.65859375])
# test_accu_orignal_m1_s3 = np.array([0.5104166666666666, 0.54375, 0.6177083333333333, 0.5572916666666666, 0.5760416666666667, 0.6010416666666667, 0.640625, 0.5895833333333333, 0.6125, 0.6104166666666667])

plt.title("Model 1: Train vs Valid Accuracy (Seed 3)")
plt.plot(epoch, train_accu_flip_m1_s3, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m1_s3, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m1_s3, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m1_s3, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m1_s3, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m1_s3, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m1_s3, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m1_s3, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m1_s3, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m1_s2, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m1_s3, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m1_s3, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# epoch = range(1, 11)
# train_accu_flip_m2_s1 = np.array([0.5748697916666666, 0.5864583333333333, 0.6348958333333333, 0.5860677083333333, 0.5235677083333333, 0.5385416666666667, 0.5, 0.5, 0.5, 0.5])
# test_accu_flip_m2_s1 = np.array([0.553125, 0.5239583333333333, 0.6104166666666667, 0.5895833333333333, 0.5145833333333333, 0.5302083333333333, 0.5, 0.5, 0.5, 0.5])
# train_accu_rotate_m2_s1 = np.array([0.5381510416666667, 0.5057291666666667, 0.6682291666666667, 0.7345052083333333, 0.7515625, 0.81171875, 0.805078125, 0.8467447916666667, 0.86328125, 0.8649739583333333])
# test_accu_rotate_m2_s1 = np.array([0.48333333333333334, 0.50625, 0.6645833333333333, 0.7114583333333333, 0.6885416666666667, 0.6958333333333333, 0.6979166666666666, 0.6979166666666666, 0.696875, 0.7052083333333333])
# train_accu_crop_m2_s1 = np.array([0.50703125, 0.5, 0.5446614583333333, 0.5455729166666666, 0.54375, 0.5576822916666667, 0.5989583333333334, 0.6609375, 0.708203125, 0.7684895833333333])
# test_accu_crop_m2_s1 = np.array([0.5, 0.4979166666666667, 0.578125, 0.5479166666666667, 0.5489583333333333, 0.5958333333333333, 0.603125, 0.64375, 0.6541666666666667, 0.640625])
# train_accu_color_m2_s1 = np.array([0.528515625, 0.5623697916666667, 0.5010416666666667, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])
# test_accu_color_m2_s1 = np.array([0.5208333333333334, 0.56875, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])
# train_accu_blur_m2_s1 = np.array([0.5259114583333333, 0.5947916666666667, 0.616796875, 0.6024739583333333, 0.63359375, 0.650390625, 0.6864583333333333, 0.6375, 0.6395833333333333, 0.6752604166666667])
# test_accu_blur_m2_s1 = np.array([0.5354166666666667, 0.5895833333333333, 0.58125, 0.575, 0.6229166666666667, 0.615625, 0.63125, 0.578125, 0.609375, 0.6104166666666667])
# train_accu_orignal_m2_s1 = np.array([0.5494791666666666, 0.571875, 0.603125, 0.6536458333333334, 0.5520833333333334, 0.69453125, 0.725, 0.8036458333333333, 0.7971354166666667, 0.85078125])
# test_accu_orignal_m2_s1 = np.array([0.5427083333333333, 0.559375, 0.5489583333333333, 0.653125, 0.5552083333333333, 0.6260416666666667, 0.6239583333333333, 0.6614583333333334, 0.6583333333333333, 0.6645833333333333])

plt.title("Model 2: Train vs Valid Accuracy (Seed 1)")
plt.plot(epoch, train_accu_flip_m2_s1, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m2_s1, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m2_s1, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m2_s1, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m2_s1, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m2_s1, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m2_s1, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m2_s1, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m2_s1, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m2_s1, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m2_s1, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m2_s1, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# epoch = range(1, 11)
# train_accu_flip_m2_s2 = np.array([0.5802083333333333, 0.5401041666666667, 0.6743489583333333, 0.717578125, 0.8065104166666667, 0.8408854166666667, 0.82578125, 0.8779947916666667, 0.8352864583333334, 0.90234375])
# test_accu_flip_m2_s2 = np.array([0.584375, 0.5489583333333333, 0.6302083333333334, 0.6541666666666667, 0.6979166666666666, 0.6833333333333333, 0.6979166666666666, 0.7447916666666666, 0.696875, 0.7479166666666667])
# train_accu_rotate_m2_s2 = np.array([0.5046875, 0.5735677083333334, 0.6537760416666667, 0.7065104166666667, 0.73671875, 0.783984375, 0.7946614583333333, 0.840625, 0.8463541666666666, 0.8592447916666667])
# test_accu_rotate_m2_s2 = np.array([0.503125, 0.5979166666666667, 0.6385416666666667, 0.690625, 0.6875, 0.6958333333333333, 0.7104166666666667, 0.7177083333333333, 0.690625, 0.7270833333333333])
# train_accu_crop_m2_s2 = np.array([0.5, 0.5072916666666667, 0.58671875, 0.6296875, 0.6752604166666667, 0.7704427083333333, 0.8477864583333333, 0.8819010416666667, 0.9044270833333333, 0.9227864583333333])
# test_accu_crop_m2_s2 = np.array([0.5, 0.509375, 0.6447916666666667, 0.6552083333333333, 0.6458333333333334, 0.6645833333333333, 0.640625, 0.6197916666666666, 0.6020833333333333, 0.6385416666666667])
# train_accu_color_m2_s2 = np.array([0.5576822916666667, 0.6638020833333333, 0.73125, 0.7352864583333333, 0.788671875, 0.86796875, 0.881640625, 0.9147135416666666, 0.9208333333333333, 0.851953125])
# test_accu_color_m2_s2 = np.array([0.5458333333333333, 0.6072916666666667, 0.60625, 0.5833333333333334, 0.6166666666666667, 0.6072916666666667, 0.621875, 0.625, 0.65625, 0.5854166666666667])
# train_accu_blur_m2_s2 = np.array([0.5748697916666666, 0.6122395833333333, 0.54375, 0.58125, 0.6657552083333333, 0.73828125, 0.800390625, 0.8692708333333333, 0.865625, 0.9001302083333333])
# test_accu_blur_m2_s2 = np.array([0.5614583333333333, 0.60625, 0.5427083333333333, 0.5677083333333334, 0.6197916666666666, 0.6020833333333333, 0.59375, 0.6114583333333333, 0.5666666666666667, 0.5916666666666667])
# train_accu_orignal_m2_s2 = np.array([0.5484375, 0.6065104166666667, 0.6338541666666667, 0.6622395833333333, 0.684375, 0.7291666666666666, 0.8015625, 0.828125, 0.8705729166666667, 0.9036458333333334])
# test_accu_orignal_m2_s2 = np.array([0.5416666666666666, 0.6010416666666667, 0.6239583333333333, 0.6270833333333333, 0.6395833333333333, 0.625, 0.6635416666666667, 0.653125, 0.6729166666666667, 0.70625])

plt.title("Model 2: Train vs Valid Accuracy (Seed 2)")
plt.plot(epoch, train_accu_flip_m2_s2, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m2_s2, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m2_s2, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m2_s2, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m2_s2, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m2_s2, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m2_s2, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m2_s2, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m2_s2, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m2_s2, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m2_s2, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m2_s2, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# epoch = range(1, 11)
# train_accu_flip_m2_s3 = np.array([0.5861979166666667, 0.5994791666666667, 0.53046875, 0.548828125, 0.6322916666666667, 0.6239583333333333, 0.7412760416666667, 0.8013020833333333, 0.83828125, 0.86796875])
# test_accu_flip_m2_s3 = np.array([0.590625, 0.6135416666666667, 0.546875, 0.5916666666666667, 0.6364583333333333, 0.5979166666666667, 0.6770833333333334, 0.7020833333333333, 0.69375, 0.7010416666666667])
# train_accu_rotate_m2_s3 = np.array([0.584375, 0.5674479166666667, 0.58125, 0.6213541666666667, 0.6904947916666667, 0.7505208333333333, 0.8036458333333333, 0.812109375, 0.7884114583333334, 0.8502604166666666])
# test_accu_rotate_m2_s3 = np.array([0.6052083333333333, 0.5822916666666667, 0.6072916666666667, 0.634375, 0.6916666666666667, 0.6875, 0.7135416666666666, 0.7114583333333333, 0.6958333333333333, 0.7291666666666666])
# train_accu_crop_m2_s3 = np.array([0.5162760416666666, 0.500390625, 0.5575520833333333, 0.5438802083333333, 0.6532552083333333, 0.7200520833333334, 0.8141927083333333, 0.8692708333333333, 0.8858072916666667, 0.9024739583333333])
# test_accu_crop_m2_s3 = np.array([0.5197916666666667, 0.5, 0.584375, 0.5677083333333334, 0.6541666666666667, 0.6572916666666667, 0.63125, 0.6489583333333333, 0.6479166666666667, 0.6354166666666666])
# train_accu_color_m2_s3 = np.array([0.596875, 0.708203125, 0.7481770833333333, 0.8018229166666667, 0.8643229166666667, 0.878515625, 0.9286458333333333, 0.9229166666666667, 0.8436197916666667, 0.89140625])
# test_accu_color_m2_s3 = np.array([0.6177083333333333, 0.6416666666666667, 0.6239583333333333, 0.6135416666666667, 0.6229166666666667, 0.628125, 0.6135416666666667, 0.634375, 0.6229166666666667, 0.6229166666666667])
# train_accu_blur_m2_s3 = np.array([0.5903645833333333, 0.6376302083333333, 0.6899739583333333, 0.515625, 0.8083333333333333, 0.786328125, 0.8817708333333333, 0.9096354166666667, 0.9157552083333333, 0.9268229166666667])
# test_accu_blur_m2_s3 = np.array([0.5833333333333334, 0.625, 0.665625, 0.5229166666666667, 0.6583333333333333, 0.671875, 0.640625, 0.6760416666666667, 0.6364583333333333, 0.6427083333333333])
# train_accu_orignal_m2_s3 = np.array([0.5666666666666667, 0.5263020833333333, 0.515625, 0.68203125, 0.7044270833333334, 0.6971354166666667, 0.7497395833333333, 0.85546875, 0.8765625, 0.8705729166666667])
# test_accu_orignal_m2_s3 = np.array([0.5520833333333334, 0.5125, 0.5104166666666666, 0.6625, 0.6333333333333333, 0.6322916666666667, 0.6239583333333333, 0.6989583333333333, 0.66875, 0.6552083333333333])

plt.title("Model 2: Train vs Valid Accuracy (Seed 3)")
plt.plot(epoch, train_accu_flip_m2_s3, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m2_s3, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m2_s3, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m2_s3, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m2_s3, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m2_s3, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m2_s3, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m2_s3, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m2_s3, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m2_s3, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m2_s3, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m2_s3, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# epoch = range(1, 11)
# train_accu_flip_m3_s1 = np.array([0.61171875, 0.6024739583333333, 0.6595052083333334, 0.58046875, 0.705078125, 0.709765625, 0.7272135416666666, 0.7536458333333333, 0.7494791666666667, 0.8138020833333334])
# test_accu_flip_m3_s1 = np.array([0.5583333333333333, 0.5333333333333333, 0.5520833333333334, 0.55, 0.6520833333333333, 0.6166666666666667, 0.6614583333333334, 0.659375, 0.6708333333333333, 0.7052083333333333])
# train_accu_rotate_m3_s1 = np.array([0.5924479166666666, 0.6110677083333333, 0.5983072916666666, 0.5955729166666667, 0.623046875, 0.6260416666666667, 0.6095052083333333, 0.6264322916666667, 0.6674479166666667, 0.6657552083333333])
# test_accu_rotate_m3_s1 = np.array([0.5260416666666666, 0.534375, 0.553125, 0.5104166666666666, 0.571875, 0.5927083333333333, 0.596875, 0.5916666666666667, 0.6052083333333333, 0.6375])
# train_accu_crop_m3_s1 = np.array([0.5279947916666666, 0.5235677083333333, 0.54765625, 0.5138020833333333, 0.5421875, 0.539453125, 0.5102864583333333, 0.5049479166666667, 0.5015625, 0.5411458333333333])
# test_accu_crop_m3_s1 = np.array([0.5114583333333333, 0.5083333333333333, 0.51875, 0.5104166666666666, 0.5177083333333333, 0.5177083333333333, 0.5072916666666667, 0.5208333333333334, 0.5114583333333333, 0.534375])
# train_accu_color_m3_s1 = np.array([0.5634114583333333, 0.5864583333333333, 0.5924479166666666, 0.625390625, 0.6708333333333333, 0.6946614583333334, 0.731640625, 0.759375, 0.7817708333333333, 0.7977864583333333])
# test_accu_color_m3_s1 = np.array([0.5197916666666667, 0.53125, 0.5802083333333333, 0.5354166666666667, 0.5770833333333333, 0.6114583333333333, 0.6447916666666667, 0.6770833333333334, 0.678125, 0.6802083333333333])
# train_accu_blur_m3_s1 = np.array([0.6130208333333333, 0.6227864583333333, 0.6419270833333334, 0.6630208333333333, 0.666015625, 0.7111979166666667, 0.7145833333333333, 0.71171875, 0.7990885416666667, 0.8326822916666666])
# test_accu_blur_m3_s1 = np.array([0.546875, 0.575, 0.5614583333333333, 0.5645833333333333, 0.6052083333333333, 0.6208333333333333, 0.615625, 0.5864583333333333, 0.6427083333333333, 0.628125])
# train_accu_orignal_m3_s1 = np.array([0.6166666666666667, 0.5770833333333333, 0.6268229166666667, 0.6265625, 0.6713541666666667, 0.68203125, 0.6666666666666666, 0.6890625, 0.69921875, 0.7325520833333333])
# test_accu_orignal_m3_s1 = np.array([0.5270833333333333, 0.525, 0.5104166666666666, 0.5635416666666667, 0.6041666666666666, 0.6135416666666667, 0.584375, 0.6114583333333333, 0.609375, 0.6458333333333334])

plt.title("Model 3: Train vs Valid Accuracy (Seed 1)")
plt.plot(epoch, train_accu_flip_m3_s1, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m3_s1, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m3_s1, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m3_s1, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m3_s1, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m3_s1, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m3_s1, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m3_s1, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m3_s1, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m3_s1, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m3_s1, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m3_s1, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# epoch = range(1, 11)
# train_accu_flip_m3_s2 = np.array([0.6076822916666667, 0.63359375, 0.6774739583333333, 0.6662760416666667, 0.6858072916666667, 0.7423177083333333, 0.7828125, 0.7947916666666667, 0.8096354166666667, 0.813671875])
# test_accu_flip_m3_s2 = np.array([0.5604166666666667, 0.5541666666666667, 0.6041666666666666, 0.5927083333333333, 0.5989583333333334, 0.6760416666666667, 0.6885416666666667, 0.7010416666666667, 0.71875, 0.6802083333333333])
# train_accu_rotate_m3_s2 = np.array([0.5845052083333333, 0.5872395833333334, 0.6205729166666667, 0.6220052083333333, 0.6131510416666667, 0.631640625, 0.6432291666666666, 0.6618489583333333, 0.681640625, 0.6640625])
# test_accu_rotate_m3_s2 = np.array([0.5364583333333334, 0.5552083333333333, 0.5697916666666667, 0.5552083333333333, 0.565625, 0.5885416666666666, 0.575, 0.5854166666666667, 0.5864583333333333, 0.6052083333333333])
# train_accu_crop_m3_s2 = np.array([0.5098958333333333, 0.5088541666666667, 0.5424479166666667, 0.55859375, 0.562109375, 0.5403645833333334, 0.5608072916666667, 0.5427083333333333, 0.551171875, 0.5669270833333333])
# test_accu_crop_m3_s2 = np.array([0.5489583333333333, 0.4875, 0.5104166666666666, 0.5104166666666666, 0.5395833333333333, 0.5395833333333333, 0.5333333333333333, 0.5260416666666666, 0.503125, 0.5427083333333333])
# train_accu_color_m3_s2 = np.array([0.5696614583333334, 0.5868489583333333, 0.6526041666666667, 0.6671875, 0.658203125, 0.7059895833333333, 0.733984375, 0.7565104166666666, 0.81015625, 0.8459635416666667])
# test_accu_color_m3_s2 = np.array([0.55, 0.54375, 0.5989583333333334, 0.590625, 0.5958333333333333, 0.621875, 0.6395833333333333, 0.6145833333333334, 0.6635416666666667, 0.6916666666666667])
# train_accu_blur_m3_s2 = np.array([0.5893229166666667, 0.59765625, 0.6416666666666667, 0.6529947916666666, 0.7213541666666666, 0.7477864583333333, 0.7928385416666667, 0.8075520833333333, 0.853515625, 0.8809895833333333])
# test_accu_blur_m3_s2 = np.array([0.559375, 0.58125, 0.5875, 0.578125, 0.60625, 0.6385416666666667, 0.6760416666666667, 0.6572916666666667, 0.6697916666666667, 0.6583333333333333])
# train_accu_orignal_m3_s2 = np.array([0.6, 0.64375, 0.6346354166666667, 0.6630208333333333, 0.6401041666666667, 0.6177083333333333, 0.6770833333333334, 0.70390625, 0.7018229166666666, 0.73515625])
# test_accu_orignal_m3_s2 = np.array([0.5239583333333333, 0.55, 0.5697916666666667, 0.596875, 0.5885416666666666, 0.5760416666666667, 0.6041666666666666, 0.6020833333333333, 0.6, 0.63125])

plt.title("Model 3: Train vs Valid Accuracy (Seed 2)")
plt.plot(epoch, train_accu_flip_m3_s2, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m3_s2, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m3_s2, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m3_s2, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m3_s2, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m3_s2, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m3_s2, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m3_s2, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m3_s2, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m3_s2, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m3_s2, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m3_s2, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# epoch = range(1, 11)
# train_accu_flip_m3_s3 = np.array([0.588671875, 0.5701822916666667, 0.63125, 0.6592447916666667, 0.6686197916666666, 0.7274739583333333, 0.7325520833333333, 0.765625, 0.7686197916666667, 0.8231770833333333])
# test_accu_flip_m3_s3 = np.array([0.5333333333333333, 0.5760416666666667, 0.5583333333333333, 0.6072916666666667, 0.6270833333333333, 0.6427083333333333, 0.6708333333333333, 0.709375, 0.6979166666666666, 0.7229166666666667])
# train_accu_rotate_m3_s3 = np.array([0.5686197916666667, 0.5916666666666667, 0.584765625, 0.5682291666666667, 0.5674479166666667, 0.6471354166666666, 0.5981770833333333, 0.6134114583333333, 0.6703125, 0.6946614583333334])
# test_accu_rotate_m3_s3 = np.array([0.50625, 0.5666666666666667, 0.5333333333333333, 0.5458333333333333, 0.525, 0.5875, 0.565625, 0.56875, 0.6354166666666666, 0.6479166666666667])
# train_accu_crop_m3_s3 = np.array([0.5299479166666666, 0.50859375, 0.5415364583333333, 0.5296875, 0.5315104166666667, 0.555078125, 0.5381510416666667, 0.5369791666666667, 0.533203125, 0.5514322916666666])
# test_accu_crop_m3_s3 = np.array([0.5333333333333333, 0.49895833333333334, 0.5364583333333334, 0.525, 0.5135416666666667, 0.525, 0.50625, 0.5145833333333333, 0.503125, 0.5645833333333333])
# train_accu_color_m3_s3 = np.array([0.5700520833333333, 0.6115885416666667, 0.5868489583333333, 0.6005208333333333, 0.5859375, 0.633203125, 0.6587239583333333, 0.6821614583333333, 0.7014322916666667, 0.7115885416666666])
# test_accu_color_m3_s3 = np.array([0.540625, 0.5395833333333333, 0.5322916666666667, 0.546875, 0.525, 0.5854166666666667, 0.63125, 0.625, 0.6385416666666667, 0.6458333333333334])
# train_accu_blur_m3_s3 = np.array([0.5807291666666666, 0.59140625, 0.5994791666666667, 0.6595052083333334, 0.698046875, 0.73828125, 0.7356770833333334, 0.7712239583333333, 0.8171875, 0.8455729166666667])
# test_accu_blur_m3_s3 = np.array([0.5354166666666667, 0.5333333333333333, 0.55625, 0.6083333333333333, 0.6291666666666667, 0.65, 0.6322916666666667, 0.659375, 0.6958333333333333, 0.7083333333333334])
# train_accu_orignal_m3_s3 = np.array([0.6145833333333334, 0.6145833333333334, 0.6122395833333333, 0.653125, 0.6408854166666667, 0.66953125, 0.69296875, 0.6911458333333333, 0.7005208333333334, 0.6703125])
# test_accu_orignal_m3_s3 = np.array([0.5520833333333334, 0.55, 0.5364583333333334, 0.56875, 0.5458333333333333, 0.596875, 0.6291666666666667, 0.6145833333333334, 0.6239583333333333, 0.5958333333333333])

plt.title("Model 3: Train vs Valid Accuracy (Seed 3)")
plt.plot(epoch, train_accu_flip_m3_s3, marker='o', markersize = 5, color='deepskyblue', label='Flip_Train')
plt.plot(epoch, test_accu_flip_m3_s3, marker='o', markersize = 5, color='deepskyblue', label='Flip_Valid', linestyle='--')
plt.plot(epoch, train_accu_rotate_m3_s3, marker='o', markersize = 5, color='red', label='Rotate_Train')
plt.plot(epoch, test_accu_rotate_m3_s3, marker='o', markersize = 5, color='red', label='Rotate_Valid', linestyle='--')
plt.plot(epoch, train_accu_crop_m3_s3, marker='o', markersize = 5, color='green', label='Crop_Train')
plt.plot(epoch, test_accu_crop_m3_s3, marker='o', markersize = 5, color='green', label='Crop_Valid', linestyle='--')
plt.plot(epoch, train_accu_color_m3_s3, marker='o', markersize = 5, color='yellow', label='Color_Train')
plt.plot(epoch, test_accu_color_m3_s3, marker='o', markersize = 5, color='yellow', label='Color_Valid', linestyle='--')
plt.plot(epoch, train_accu_blur_m3_s3, marker='o', markersize = 5, color='magenta', label='Blur_Train')
plt.plot(epoch, test_accu_blur_m3_s3, marker='o', markersize = 5, color='magenta', label='Blur_Valid', linestyle='--')
plt.plot(epoch, train_accu_orignal_m3_s3, marker='o', markersize = 5, color='black', label='Orignal_Train')
plt.plot(epoch, test_accu_orignal_m3_s3, marker='o', markersize = 5, color='black', label='Orignal_Valid', linestyle='--')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()
